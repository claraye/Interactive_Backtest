# %%
import backtest as bt
import pandas as pd
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
pnls_df = pd.read_csv('rsi_values_5y.csv', header=None, index_col=0)[1]
initial_cash = 1000000
performance = bt.performance_analysis_MF(pnls_df, initial_cash)
# Out:
# (1247,)
# Begin                        2014-11-20 00:00:00
# End                          2019-11-01 00:00:00
# Duration                      1807 days 00:00:00
# Initial_Value                            1000000
# Highest_Value                        1.34231e+07
# Lowest_Value                              113891
# Final_Value                          1.32638e+07
# Total_Return                             12.2638
# Total_Return_(Annualized)               0.686772
# Volatility_(Annualized)                  2.86418
# Max_Drawdown                            -0.93005
# Avg_Drawdown                           -0.160814
# Sharpe_Ratio                            0.743282
# Sortino_Ratio                            2.13997
# Relative_Return                         0.601753
# Relative_Vol                             2.72818
# Relative_Max_DD                        -0.732268
# Relative_Avg_DD                        -0.131608
# Information_Ratio                       0.213733
# dtype: object
# ...
